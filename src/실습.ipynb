# %%
import os
import pandas as pd

# %%
os.getcwd()
# Out:
# '/workspaces/lgcns-mlops-practice/src'

# %%
DATA_PATH  = os.path.join(os.getcwd(), "data")

# %%
DATA_PATH = '/workspaces/lgcns-mlops-practice/data/'

# %%
DATA_PATH
# Out:
# '/workspaces/lgcns-mlops-practice/src/data'

# %%
df = pd.read_csv(os.path.join(DATA_PATH, "house_rent_train.csv"))

# %%
df
# Out:
#        posted_on  bhk   rent  size            floor    area_type
# 0     2022-04-23    2   7000   450       1 out of 3  Carpet Area  \
# 1     2022-04-23    1   6500   800  Ground out of 1  Carpet Area
# 2     2022-04-23    2  20000   700       1 out of 2   Super Area
# 3     2022-04-23    3  36125  1700  Ground out of 2   Super Area
# 4     2022-04-23    2   8000   650       1 out of 2   Super Area
# ...          ...  ...    ...   ...              ...          ...
# 2688  2022-06-15    2  13000   650  Ground out of 4  Carpet Area
# 2689  2022-06-15    2  11000   700  Ground out of 2  Carpet Area
# 2690  2022-06-15    3  16000  1305       2 out of 5   Super Area
# 2691  2022-06-15    1   6000   300       1 out of 2  Carpet Area
# 2692  2022-06-15    3  20000  1100  Ground out of 1  Carpet Area
#
#                   area_locality       city furnishing_status
# 0                     safuipara    Kolkata         Furnished  \
# 1                   Santragachi    Kolkata       Unfurnished
# 2       Salt Lake City Sector 1    Kolkata         Furnished
# 3                Salt Lake City    Kolkata       Unfurnished
# 4          Garia Station, Garia    Kolkata       Unfurnished
# ...                         ...        ...               ...
# 2688               Lake Gardens    Kolkata    Semi-Furnished
# 2689                Uttarahalli  Bangalore    Semi-Furnished
# 2690                 Bowenpally  Hyderabad    Semi-Furnished
# 2691  Picnic Garden, E M Bypass    Kolkata       Unfurnished
# 2692    Salt Lake City Sector 2    Kolkata       Unfurnished
#
#       tenant_preferred  bathroom point_of_contact
# 0            Bachelors         2    Contact Owner
# 1     Bachelors/Family         1    Contact Owner
# 2     Bachelors/Family         1    Contact Owner
# 3     Bachelors/Family         2    Contact Owner
# 4     Bachelors/Family         1    Contact Owner
# ...                ...       ...              ...
# 2688  Bachelors/Family         2    Contact Owner
# 2689  Bachelors/Family         2    Contact Owner
# 2690  Bachelors/Family         2    Contact Owner
# 2691  Bachelors/Family         1    Contact Agent
# 2692         Bachelors         2    Contact Agent
#
# [2693 rows x 12 columns]

# %%
floor_extractor(df, "floor")
# Out:
#        posted_on  bhk   rent  size  floor    area_type
# 0     2022-04-23    2   7000   450      1  Carpet Area  \
# 1     2022-04-23    1   6500   800      0  Carpet Area
# 2     2022-04-23    2  20000   700      1   Super Area
# 3     2022-04-23    3  36125  1700      0   Super Area
# 4     2022-04-23    2   8000   650      1   Super Area
# ...          ...  ...    ...   ...    ...          ...
# 2688  2022-06-15    2  13000   650      0  Carpet Area
# 2689  2022-06-15    2  11000   700      0  Carpet Area
# 2690  2022-06-15    3  16000  1305      2   Super Area
# 2691  2022-06-15    1   6000   300      1  Carpet Area
# 2692  2022-06-15    3  20000  1100      0  Carpet Area
#
#                   area_locality       city furnishing_status
# 0                     safuipara    Kolkata         Furnished  \
# 1                   Santragachi    Kolkata       Unfurnished
# 2       Salt Lake City Sector 1    Kolkata         Furnished
# 3                Salt Lake City    Kolkata       Unfurnished
# 4          Garia Station, Garia    Kolkata       Unfurnished
# ...                         ...        ...               ...
# 2688               Lake Gardens    Kolkata    Semi-Furnished
# 2689                Uttarahalli  Bangalore    Semi-Furnished
# 2690                 Bowenpally  Hyderabad    Semi-Furnished
# 2691  Picnic Garden, E M Bypass    Kolkata       Unfurnished
# 2692    Salt Lake City Sector 2    Kolkata       Unfurnished
#
#       tenant_preferred  bathroom point_of_contact
# 0            Bachelors         2    Contact Owner
# 1     Bachelors/Family         1    Contact Owner
# 2     Bachelors/Family         1    Contact Owner
# 3     Bachelors/Family         2    Contact Owner
# 4     Bachelors/Family         1    Contact Owner
# ...                ...       ...              ...
# 2688  Bachelors/Family         2    Contact Owner
# 2689  Bachelors/Family         2    Contact Owner
# 2690  Bachelors/Family         2    Contact Owner
# 2691  Bachelors/Family         1    Contact Agent
# 2692         Bachelors         2    Contact Agent
#
# [2693 rows x 12 columns]

# %%
import numpy as np
import pandas as pd
from category_encoders import TargetEncoder
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import FunctionTransformer

CAT_FEATURES = [
    "area_type",
    "city",
    "furnishing_status",
    "tenant_preferred",
    "point_of_contact",
]


def extract_floor(floor_info: str) -> int:
    """층수 컬럼에서 실제 층수만 추출합니다.

    현재 층수 정보는 'X out of Y'로 되어 있습니다.
    여기에서 X만 추출하여 정수로 반환합니다.
    Upper basement, Lower basement, Ground out 등은 모두 0층으로 변환합니다.

    Args:
        floor_info (str): 층수 정보
    """
    # TODO
    split_floor_info = floor_info.split()
    floor_str = split_floor_info[0]
    return int(floor_str) if floor_str.isnumeric() else 0

def floor_extractor(df: pd.DataFrame, col: str) -> pd.DataFrame:
    """`extract_floor()` 함수를 `FunctionTransformer`에 사용하기 위한
    Wrapping function입니다.

    Args:
        df (pd.DataFrame): 데이터프레임
        col (str): `extract_floor()`를 적용할 컬럼명
            `Floor`만 사용해야 함

    Returns:
        pd.DataFrame: 컬럼 처리 후 데이터
    """
    df[col] = df[col].apply(lambda x: extract_floor(x))
    return df

# %%
# TODO: 전처리 파이프라인 작성
# 1. 방의 크기는 제곱근을 적용함 (FunctionTransformer 사용)
# 2. 층수는 실제 층수를 추출하되 숫자가 아닌 Basement 등은 0층으로 표기함 .  dd
# 3. 범주형 변수(CAT_FEATURES)는 타겟 인코딩 적용 (from category_encoders import TargetEncoder)
preprocess_pipeline = ColumnTransformer(
    transformers=[
        ("sqrt_transformer", FunctionTransformer(np.sqrt), ["size"]),
        (
            "floor_extractor",
            FunctionTransformer(floor_extractor, kw_args={"col": "floor"}),
            ["floor"],
        ),
        ("target_encoder", TargetEncoder(), CAT_FEATURES),
    ],
    remainder="passthrough",
    verbose_feature_names_out=False,
)
preprocess_pipeline.set_output(transform="pandas")
# Out:
# /workspaces/lgcns-mlops-practice/.venv/lib/python3.9/site-packages/sklearn/preprocessing/_function_transformer.py:343: UserWarning: With transform="pandas", `func` should return a DataFrame to follow the set_output API.
#   warnings.warn(
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('sqrt_transformer',
#                                  FunctionTransformer(func=<ufunc 'sqrt'>),
#                                  ['size']),
#                                 ('floor_extractor',
#                                  FunctionTransformer(func=<function floor_extractor at 0x7fb2dc9c94c0>,
#                                                      kw_args={'col': 'floor'}),
#                                  ['floor']),
#                                 ('target_encoder', TargetEncoder(),
#                                  ['area_type', 'city', 'furnishing_status',
#                                   'tenant_preferred', 'point_of_contact'])],
#                   verbose_feature_names_out=False)
